# %% [markdown]
# # Pandas practice (part 1)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Contents:
#
# 1. `SettingWithCopyWarning` issues with Pandas
# 1. Create and inspect data frames
# 1. Subset columns
# 1. Subset rows
# 1. Add new columns
# 1. Modify columns
# 1. Delete columns
# 1. Concatenate DFs vertically

# %% [markdown]
# ## `SettingWithCopyWarning` issues with Pandas
#
# Indepth reading: https://www.dataquest.io/blog/settingwithcopywarning/
#
# Key points:
#
# - Always use `.copy()` when create a new DF from the original DF.
# - When access and set values, use `.loc[]`
# - Avoid chained assignment and hidden chaining

# %%
df = pd.read_csv("data/example_data.csv", sep=";") # Comma-separated values

# %%
df.head()
# Out:
#                       time                                  place magType  \
# 0  2018-10-13 11:10:23.560        262km NW of Ozernovskiy, Russia     mww
# 1  2018-10-13 04:34:15.580            25km E of Bitung, Indonesia     mww
# 2  2018-10-13 00:13:46.220              42km WNW of Sola, Vanuatu     mww
# 3  2018-10-12 21:09:49.240  13km E of Nueva Concepcion, Guatemala     mww
# 4  2018-10-12 02:52:03.620    128km SE of Kimbe, Papua New Guinea     mww
#
#    mag  alert  tsunami
# 0  6.7  green        1
# 1  5.2  green        0
# 2  5.7  green        0
# 3  5.7  green        0
# 4  5.6  green        1

# %%
df = pd.read_csv("data/example_data.csv", sep=";")
print(df.shape)
df.head()
# Out:
# (5, 6)
#                       time                                  place magType  \
# 0  2018-10-13 11:10:23.560        262km NW of Ozernovskiy, Russia     mww
# 1  2018-10-13 04:34:15.580            25km E of Bitung, Indonesia     mww
# 2  2018-10-13 00:13:46.220              42km WNW of Sola, Vanuatu     mww
# 3  2018-10-12 21:09:49.240  13km E of Nueva Concepcion, Guatemala     mww
# 4  2018-10-12 02:52:03.620    128km SE of Kimbe, Papua New Guinea     mww
#
#    mag  alert  tsunami
# 0  6.7  green        1
# 1  5.2  green        0
# 2  5.7  green        0
# 3  5.7  green        0
# 4  5.6  green        1

# %%
df2 = df.copy()

# %% [markdown]
# ### Issue 1: chained assignment

# %% [markdown]
# Pandas generates the warning when it detects something called chained assignment. Here are some terms:
#
# - `Assignment`: Operations that set the value of something. Example: `df = pd.read_csv("data/example_data.csv", sep=";")`. Often referred to as a `set` operation.
# - `Access`: Operations that return the value of something such as the below examples of indexing and chaining. Often referred to as a `get` operations.
# - `Indexing`: Any assignment or access method that references a subset of the data; for example `data[1:5]`.
# - `Chaining`: The use of more than one indexing operation back-to-back; for example `data[1:5][1:3]`.

# %% [markdown]
# #### Not work, and produce warning

# %%
df2.loc[df2["tsunami"] == 1]["alert"] = "red"
# Out:
# C:\Users\tue\programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Reasons: We have chained two indexing operations together.
#
# - First one: `[df2["tsunami"] == 1]`
# - Second one: `["alert"]`
#
# - These two chained operations execute independently, one after another.
# - The first is an access method (get operation), that will return a DataFrame containing all rows where `tsunami` equals `1`.
# - The second is an assignment operation (set operation), that is called on this new DataFrame.
# - We are not operating on the original DataFrame at all.
# - Therefore, `alert` did not change.

# %% [markdown]
# #### Work, no warning

# %%
df2.loc[df2["tsunami"] == 1, "alert"] = "red"
df2.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Issue 2: Hidden chainning

# %%
# Create a copy
df2 = df.copy()
df2.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
# Create tsunami_1 from df2 where tsunami = 1
# tsunami_1 can be a copy or a view to df2, we don't know
tsunami_1 = df2.loc[df2["tsunami"] == 1, :]
tsunami_1.head(2)
# Out:
#      alert  cdi      code                                             detail  \
# 36     NaN  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118  green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt   gap                                 ids  mag magType  ...  \
# 36   1.541   NaN  51.0                        ,us1000hbsa,  5.0     mww  ...
# 118  2.623   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.7     mww  ...
#
#         sources    status           time  \
# 36         ,us,  reviewed  1539459504090
# 118  ,pt,at,us,  reviewed  1539429023560
#
#                                                  title  tsunami        type  \
# 36   M 5.0 - 165km NNW of Flying Fish Cove, Christm...        1  earthquake
# 118            M 6.7 - 262km NW of Ozernovskiy, Russia        1  earthquake
#
#                                                  types     tz        updated  \
# 36                        ,geoserve,origin,phase-data,  420.0  1539461285040
# 118  ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
#
#                                                    url
# 36   https://earthquake.usgs.gov/earthquakes/eventp...
# 118  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
df2.loc[df2["tsunami"] == 1, :].head(2)
# Out:
#      alert  cdi      code                                             detail  \
# 36     NaN  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118  green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt   gap                                 ids  mag magType  ...  \
# 36   1.541   NaN  51.0                        ,us1000hbsa,  5.0     mww  ...
# 118  2.623   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.7     mww  ...
#
#         sources    status           time  \
# 36         ,us,  reviewed  1539459504090
# 118  ,pt,at,us,  reviewed  1539429023560
#
#                                                  title  tsunami        type  \
# 36   M 5.0 - 165km NNW of Flying Fish Cove, Christm...        1  earthquake
# 118            M 6.7 - 262km NW of Ozernovskiy, Russia        1  earthquake
#
#                                                  types     tz        updated  \
# 36                        ,geoserve,origin,phase-data,  420.0  1539461285040
# 118  ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
#
#                                                    url
# 36   https://earthquake.usgs.gov/earthquakes/eventp...
# 118  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
# Set alert column of tsunami_1 to 'red'
# Will produce warning
tsunami_1["alert"] = 'red'
# Out:
# C:\Users\tue\programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# View
tsunami_1.head(2)
# Out:
#     alert  cdi      code                                             detail  \
# 36    red  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118   red  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt   gap                                 ids  mag magType  ...  \
# 36   1.541   NaN  51.0                        ,us1000hbsa,  5.0     mww  ...
# 118  2.623   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.7     mww  ...
#
#         sources    status           time  \
# 36         ,us,  reviewed  1539459504090
# 118  ,pt,at,us,  reviewed  1539429023560
#
#                                                  title  tsunami        type  \
# 36   M 5.0 - 165km NNW of Flying Fish Cove, Christm...        1  earthquake
# 118            M 6.7 - 262km NW of Ozernovskiy, Russia        1  earthquake
#
#                                                  types     tz        updated  \
# 36                        ,geoserve,origin,phase-data,  420.0  1539461285040
# 118  ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
#
#                                                    url
# 36   https://earthquake.usgs.gov/earthquakes/eventp...
# 118  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
# View df2
df2.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
# To prevent this, we EXPLICITLY make a copy when create tsunami_1
# No warnings
tsunami_1 = df2.loc[df2["tsunami"] == 1, :].copy()
tsunami_1.head(2)
# Out:
#      alert  cdi      code                                             detail  \
# 36     NaN  NaN  1000hbsa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118  green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt   gap                                 ids  mag magType  ...  \
# 36   1.541   NaN  51.0                        ,us1000hbsa,  5.0     mww  ...
# 118  2.623   NaN  25.0  ,pt18286001,at00pgjb1a,us1000hbkz,  6.7     mww  ...
#
#         sources    status           time  \
# 36         ,us,  reviewed  1539459504090
# 118  ,pt,at,us,  reviewed  1539429023560
#
#                                                  title  tsunami        type  \
# 36   M 5.0 - 165km NNW of Flying Fish Cove, Christm...        1  earthquake
# 118            M 6.7 - 262km NW of Ozernovskiy, Russia        1  earthquake
#
#                                                  types     tz        updated  \
# 36                        ,geoserve,origin,phase-data,  420.0  1539461285040
# 118  ,geoserve,ground-failure,impact-link,losspager...  600.0  1539455437040
#
#                                                    url
# 36   https://earthquake.usgs.gov/earthquakes/eventp...
# 118  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
tsunami_1["alert"] = "red"

# %%
df2.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
df2.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Turn off warnings
# - Not recommended.
# - But in case you really want: `pd.set_option('mode.chained_assignment', mode)`
#     - `mode=None`: to switch off the warning entirely
#     - `mode='warn'`: to generate a warning (default)
#     - `mode='raise'`: to raise an exception instead of a warning (stop program)

# %% [markdown]
# ## Create and inspect data frames

# %% [markdown]
# ### Tạo data frame từ `data/earthquakes.csv`

# %%
df = pd.read_csv("data/earthquakes.csv")

# %% [markdown]
# ### Show 3 dòng đầu, 3 dòng cuối

# %%
df.head(3)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0  21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [3 rows x 26 columns]

# %%
df.tail(3)
# Out:
#      alert  cdi        code  \
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail     dmin  felt    gap  \
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.45260   NaN  276.0
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01865   NaN   61.0
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.01698   NaN   39.0
#
#                  ids   mag magType  ...  sources    status           time  \
# 9329  ,pr2018261000,  2.40      md  ...     ,pr,  reviewed  1537229908180
# 9330    ,ci38063959,  1.10      ml  ...     ,ci,  reviewed  1537229545350
# 9331    ,ci38063935,  0.66      ml  ...     ,ci,  reviewed  1537228864470
#
#                                          title  tsunami        type  \
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico        0  earthquake
# 9330             M 1.1 - 9km NE of Aguanga, CA        0  earthquake
# 9331             M 0.7 - 9km NE of Aguanga, CA        0  earthquake
#
#                                                   types     tz        updated  \
# 9329                       ,geoserve,origin,phase-data, -240.0  1537243777410
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url
# 9329  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [3 rows x 26 columns]

# %% [markdown]
# ### In số dòng, số cột

# %%
df.shape[0]
# Out:
# 9332

# %%
df.shape[1]
# Out:
# 26

# %% [markdown]
# ### In ra kiểu dữ liệu của mỗi cột

# %%
df.dtypes
# Out:
# alert       object
# cdi        float64
# code        object
# detail      object
# dmin       float64
# felt       float64
# gap        float64
# ids         object
# mag        float64
# magType     object
# mmi        float64
# net         object
# nst        float64
# place       object
# rms        float64
# sig          int64
# sources     object
# status      object
# time         int64
# title       object
# tsunami      int64
# type        object
# types       object
# tz         float64
# updated      int64
# url         object
# dtype: object

# %% [markdown]
# ### Lấy list tên các cột

# %%
df.columns.tolist()
# Out:
# ['alert',
#  'cdi',
#  'code',
#  'detail',
#  'dmin',
#  'felt',
#  'gap',
#  'ids',
#  'mag',
#  'magType',
#  'mmi',
#  'net',
#  'nst',
#  'place',
#  'rms',
#  'sig',
#  'sources',
#  'status',
#  'time',
#  'title',
#  'tsunami',
#  'type',
#  'types',
#  'tz',
#  'updated',
#  'url']

# %% [markdown]
# ### Dùng `.info()` để lấy thêm thông tin về null value và kiểu dữ liệu của từng cột

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
#  20  tsunami  9332 non-null   int64
#  21  type     9332 non-null   object
#  22  types    9332 non-null   object
#  23  tz       9331 non-null   float64
#  24  updated  9332 non-null   int64
#  25  url      9332 non-null   object
# dtypes: float64(9), int64(4), object(13)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Lọc ra các cột kiểu số lưu vào `df_num`, show 3 dòng đầu

# %%
df_num = df.select_dtypes("number")

# %%
df_num.head(3)
# Out:
#    cdi      dmin  felt   gap   mag  mmi    nst   rms  sig           time  \
# 0  NaN  0.008693   NaN  85.0  1.35  NaN   26.0  0.19   28  1539475168010
# 1  NaN  0.020030   NaN  79.0  1.29  NaN   20.0  0.29   26  1539475129610
# 2  4.4  0.021370  28.0  21.0  3.42  NaN  111.0  0.22  192  1539475062610
#
#    tsunami     tz        updated
# 0        0 -480.0  1539475395144
# 1        0 -480.0  1539475253925
# 2        0 -480.0  1539536756176

# %%
df_num.dtypes
# Out:
# cdi        float64
# dmin       float64
# felt       float64
# gap        float64
# mag        float64
# mmi        float64
# nst        float64
# rms        float64
# sig          int64
# time         int64
# tsunami      int64
# tz         float64
# updated      int64
# dtype: object

# %% [markdown]
# ### Lọc ra các cột kiểu object lưu vào `df_cat`, show 3 dòng đầu

# %%
df_cat = df.select_dtypes("O")

# %%
df_cat.head(3)
# Out:
#   alert      code                                             detail  \
# 0   NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#             ids magType net                  place sources     status  \
# 0  ,ci37389218,      ml  ci  9km NE of Aguanga, CA    ,ci,  automatic
# 1  ,ci37389202,      ml  ci  9km NE of Aguanga, CA    ,ci,  automatic
# 2  ,ci37389194,      ml  ci  8km NE of Aguanga, CA    ,ci,  automatic
#
#                            title        type  \
# 0  M 1.4 - 9km NE of Aguanga, CA  earthquake
# 1  M 1.3 - 9km NE of Aguanga, CA  earthquake
# 2  M 3.4 - 8km NE of Aguanga, CA  earthquake
#
#                                                types  \
# 0         ,geoserve,nearby-cities,origin,phase-data,
# 1         ,geoserve,nearby-cities,origin,phase-data,
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o...
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...

# %%
df_cat.dtypes
# Out:
# alert      object
# code       object
# detail     object
# ids        object
# magType    object
# net        object
# place      object
# sources    object
# status     object
# title      object
# type       object
# types      object
# url        object
# dtype: object

# %% [markdown]
# ### Tính descriptive stats cho `df_cat`

# %%
df_cat.describe()
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  80313319  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,ci37362946,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# top     M 0.4 - 10km NE of Aguanga, CA  earthquake
# freq                                55        9081
#
#                                types  \
# count                           9332
# unique                            42
# top     ,geoserve,origin,phase-data,
# freq                            5301
#
#                                                       url
# count                                                9332
# unique                                               9332
# top     https://earthquake.usgs.gov/earthquakes/eventp...
# freq                                                    1

# %% [markdown]
# ### Tính descriptive stats cho `df_num`

# %%
df_num.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 25%     2.680000     8.000000     0.119675     8.000000  1.537793e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 75%     4.570000    25.000000     0.590000    56.000000  1.538766e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 25%       0.000000  -540.000000  1.537996e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 75%       0.000000  -480.000000  1.539110e+12
# max       1.000000   720.000000  1.539537e+12

# %% [markdown]
# ### Dùng tham số `include, exclude` của `.describe()` để tính summary statistics

# %%
df.describe(include="number")
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# min     0.000000     0.000000     0.000000     0.000000  1.537229e+12
# 25%     2.680000     8.000000     0.119675     8.000000  1.537793e+12
# 50%     3.720000    15.000000     0.210000    26.000000  1.538245e+12
# 75%     4.570000    25.000000     0.590000    56.000000  1.538766e+12
# max     9.120000   172.000000     1.910000  2015.000000  1.539475e+12
#
#            tsunami           tz       updated
# count  9332.000000  9331.000000  9.332000e+03
# mean      0.006537  -451.990140  1.538537e+12
# std       0.080589   231.752571  6.564135e+08
# min       0.000000  -720.000000  1.537230e+12
# 25%       0.000000  -540.000000  1.537996e+12
# 50%       0.000000  -480.000000  1.538621e+12
# 75%       0.000000  -480.000000  1.539110e+12
# max       1.000000   720.000000  1.539537e+12

# %%
df.describe(include="O")
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  80313319  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,ci37362946,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# top     M 0.4 - 10km NE of Aguanga, CA  earthquake
# freq                                55        9081
#
#                                types  \
# count                           9332
# unique                            42
# top     ,geoserve,origin,phase-data,
# freq                            5301
#
#                                                       url
# count                                                9332
# unique                                               9332
# top     https://earthquake.usgs.gov/earthquakes/eventp...
# freq                                                    1

# %% [markdown]
# ### Dùng `.unique()` và `.value_counts()` để inspect các cột categorical
#
# Ví dụ cột `type`

# %%
df["alert"].unique()
# Out:
# array([nan, 'green', 'red'], dtype=object)

# %%
df["alert"].value_counts(normalize=True)
# Out:
# green    0.983051
# red      0.016949
# Name: alert, dtype: float64

# %% [markdown]
# ## Subset columns

# %% [markdown]
# ### Trích xuất cột `type` thành series `s`
# - In 5 phần tử đầu của `s`
# - Describe series `s`

# %%
s = df["type"]

# %%
s.head(5)
# Out:
# 0    earthquake
# 1    earthquake
# 2    earthquake
# 3    earthquake
# 4    earthquake
# Name: type, dtype: object

# %% [markdown]
# ### Trích xuất cột `type` thành data frame `df_type`
# - `df_type` chỉ có 1 cột `type`
# - Describe `df_type`

# %%
df_type = df[["type"]]
df_type.head(5)
# Out:
#          type
# 0  earthquake
# 1  earthquake
# 2  earthquake
# 3  earthquake
# 4  earthquake

# %% [markdown]
# ### Dùng `.filter()` để subset cột
# - Lọc ra cột có tên chứa `mag`
# - Lọc ra cột có tên bắt đầu bởi `ti`
# - Lọc ra cột có tên kết thúc bởi `s`

# %%
df.filter(regex="^mag").head(3)
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml

# %%
df.filter(regex="^ti").head(3)
# Out:
#             time                          title
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA

# %%
df.filter(regex="s$").head(3)
# Out:
#             ids   rms sources     status  \
# 0  ,ci37389218,  0.19    ,ci,  automatic
# 1  ,ci37389202,  0.29    ,ci,  automatic
# 2  ,ci37389194,  0.22    ,ci,  automatic
#
#                                                types
# 0         ,geoserve,nearby-cities,origin,phase-data,
# 1         ,geoserve,nearby-cities,origin,phase-data,
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o...

# %% [markdown]
# ## Subset rows

# %% [markdown]
# ### Lấy những dòng có `mag >= 0.7`
# - Có bao nhiêu rows?

# %%
df.loc[df["mag"] >= 0.7, :].shape[0]
# Out:
# 7136

# %% [markdown]
# ### Lấy những dòng có `tsunami = 1` VÀ `alert = 'red'`
#
# - Có bao nhiêu rows?

# %%
cond = (df["tsunami"] == 1) & (df["alert"] == "red")
df.loc[cond, :].shape[0]
# Out:
# 1

# %% [markdown]
# ### Lấy những dòng có `tsunami = 1` HOẶC `alert = 'red'`
#
# - Có bao nhiêu rows?

# %%
cond = (df["tsunami"] == 1) | (df["alert"] == "red")
df.loc[cond, :].shape[0]
# Out:
# 61

# %% [markdown]
# ### Tạo series giá trị `mag` của những dòng có `tsunami = 1` HOẶC `alert = 'red'`
#
# - Tính avg mag của series này

# %%
cond = (df["tsunami"] == 1) | (df["alert"] == "red")
df.loc[cond, "mag"].mean()
# Out:
# 5.3580327868852455

# %% [markdown]
# ### Tạo DF gồm cột `mag` và `type` của những dòng có `tsunami = 1` HOẶC `alert = 'red'`
# - In ra 3 dòng đầu

# %%
cond = (df["tsunami"] == 1) | (df["alert"] == "red")
df.loc[cond, ["mag", "type"]].head(3)
# Out:
#      mag        type
# 36   5.0  earthquake
# 118  6.7  earthquake
# 501  5.6  earthquake

# %% [markdown]
# ### Lọc ra những dòng có `type` là `earthquake`, `ice quake`, hoặc `explosion`
# - Dùng `.isin()`
# - Có bao nhiêu dòng

# %%
values = ["earthquake", "ice quake", "explosion"]
df.loc[df["type"].isin(values), :].shape
# Out:
# (9233, 26)

# %% [markdown]
# ## Add new columns
#
# - Tạo `df2` là copy của df với những cột sau `['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']`
# - Thực hiện các thao tác sau trên `df2`

# %%
cols = [
    'time', 'title', 'place', 
    'magType', 'mag', 'alert', 'tsunami'
]

df2 = df.loc[:, cols].copy()

# %% [markdown]
# ### Thêm cột `ones` với giá trị `1`

# %%
df2["ones"] = 1

# %%
df2.head(2)
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
#
#   magType   mag alert  tsunami  ones
# 0      ml  1.35   NaN        0     1
# 1      ml  1.29   NaN        0     1

# %% [markdown]
# ### Thêm cột `mag_sign` với giá trị `-1, 0, 1` thể hiện dấu của `mag`

# %% [markdown]
# Cách 1

# %%
df2["mag_sign"] = None
df2.loc[df["mag"] > 0, "mag_sign"] = 1
df2.loc[df["mag"] < 0, "mag_sign"] = -1
df2.loc[df["mag"] == 0, "mag_sign"] = 0

# %%
df2["mag_sign"].value_counts()
# Out:
#  1.0    8792
# -1.0     491
#  0.0      48
# Name: mag_sign, dtype: int64

# %% [markdown]
# Cách 2

# %%
df2["mag_sign"] = df2["mag"].apply(np.sign)

# %%
df2["mag_sign"].value_counts()
# Out:
#  1.0    8792
# -1.0     491
#  0.0      48
# Name: mag_sign, dtype: int64

# %% [markdown]
# ## Modify columns
#
# - Tạo `df2` là copy của df với những cột sau `['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']`
# - Thực hiện các thao tác sau trên `df2`

# %%
df2 = df.loc[:, ['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']].copy()

# %% [markdown]
# ### Nhân `mag` với 100 và gán lại vào mag

# %%
df2["mag"] = df["mag"] * 100

# %%
df2.head(2)
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
#
#   magType    mag alert  tsunami  ones  mag_sign
# 0      ml  135.0   NaN        0     1       1.0
# 1      ml  129.0   NaN        0     1       1.0

# %% [markdown]
# ### Biến `place` thành uppercase, lưu lại thay đổi

# %%
df2["place"] = df2["place"].str.upper()

# %%
df2.head(2)
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9KM NE OF AGUANGA, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9KM NE OF AGUANGA, CA
#
#   magType    mag alert  tsunami  ones  mag_sign
# 0      ml  135.0   NaN        0     1       1.0
# 1      ml  129.0   NaN        0     1       1.0

# %% [markdown]
# ## Delete columns
#
# - Tạo `df2` là copy của df với những cột sau `['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']`
# - Thực hiện các thao tác sau trên `df2`

# %%
df2 = df.loc[:, ['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']].copy()

# %%
df2.head(2)
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
#
#   magType   mag alert  tsunami
# 0      ml  1.35   NaN        0
# 1      ml  1.29   NaN        0

# %% [markdown]
# ### Xóa cột time dùng `del`

# %%
del df2["time"]

# %%
df2.head(2)
# Out:
#                            title                  place magType   mag alert  \
# 0  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA      ml  1.35   NaN
# 1  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA      ml  1.29   NaN
#
#    tsunami
# 0        0
# 1        0

# %% [markdown]
# ### Pop cột `mag`, gán vào biến `mag` và xóa cột `mag`

# %%
mag = df2.pop("mag")

# %%
df2.head(2)
# Out:
#                            title                  place magType alert  tsunami
# 0  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA      ml   NaN        0
# 1  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA      ml   NaN        0

# %% [markdown]
# ### Xóa nhiều cột cùng lúc dùng `.drop()`
# - Xóa cột `title`, `place`, và `alert`
# - Muốn lưu thay đổi thì set `inplace=True`

# %%
# Cách 1: set axis=1
df2.drop(["title", "place", "alert"], axis=1, inplace=True)

# %%
df2.head(2)
# Out:
#   magType  tsunami
# 0      ml        0
# 1      ml        0

# %% [markdown]
# Tạo lại df2

# %%
df2 = df.loc[:, ['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']].copy()

# %%
# Cách 2: truyền columns
df2.drop(columns=["title", "place", "alert"], inplace=True)

# %% [markdown]
# ## Concat 2 DFs vertically
# Tạo 2 DFs là `ts_0` và `ts_1` với `tsunami` lần lượt là 0 và 1. Chỉ lấy các cột `'mag', 'alert', 'tsunami'`

# %%
cols = ['mag', 'alert', 'tsunami']

ts_0 = df.loc[df["tsunami"] == 0, cols] # Data source 1
ts_1 = df.loc[df["tsunami"] == 1, cols] # Data source 2

# %%
ts_0.head(2)
# Out:
#     mag alert  tsunami
# 0  1.35   NaN        0
# 1  1.29   NaN        0

# %%
ts_1.head(1)
# Out:
#     mag alert  tsunami
# 36  5.0   NaN        1

# %% [markdown]
# ### Chồng `ts_0` và `ts_1` lên nhau dùng `pd.concat()`
#
# - Lưu ý nên set `ignore_index=True` để reset lại index ở kết quả

# %%
pd.concat([ts_0, ts_1], ignore_index=True)
# Out:
#        mag  alert  tsunami
# 0     1.35    NaN        0
# 1     1.29    NaN        0
# 2     3.42    NaN        0
# 3     0.44    NaN        0
# 4     2.16    NaN        0
# ...    ...    ...      ...
# 9327  5.40    NaN        1
# 9328  5.10    NaN        1
# 9329  5.10  green        1
# 9330  5.20    NaN        1
# 9331  5.10    NaN        1
#
# [9332 rows x 3 columns]
