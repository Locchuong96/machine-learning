# %% [markdown]
# - competition link: https://www.kaggle.com/c/sorghum-id-fgvc-9/data
#
# - dataset: `kaggle competitions download -c sorghum-id-fgvc-9`

# %%
from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp /content/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c sorghum-id-fgvc-9
# Out:
# ...
# 100% 66.5G/66.6G [11:04<00:01, 58.8MB/s]

# %%
# move to drive

# %% [markdown]
# - Download your competitions: `! kaggle competitions download <name-of-competition>`
#
# - Download your datasets: `! kaggle datasets download <name-of-dataset>`

# %%
! unzip /content/sorghum-id-fgvc-9.zip -d competition
# Out:
# Archive:  /content/sorghum-id-fgvc-9.zip
#   inflating: competition/sample_submission.csv
#   inflating: competition/test/1000005362.png
#   inflating: competition/test/1000099707.png
#   inflating: competition/test/1000135300.png
#   inflating: competition/test/1000136796.png
#   inflating: competition/test/1000292439.png
#   inflating: competition/test/1000350798.png
#   inflating: competition/test/100043618.png
#   inflating: competition/test/1000556805.png
#   inflating: competition/test/1000673645.png
#   inflating: competition/test/1000720114.png
#   inflating: competition/test/1000826475.png
#   inflating: competition/test/1000856201.png
#   inflating: competition/test/1000961485.png
#   inflating: competition/test/1001162778.png
#   inflating: competition/test/1001197278.png
#   inflating: competition/test/1001370074.png
#   inflating: competition/test/1001378931.png
#   inflating: competition/test/1001413857.png
#   inflating: competition/test/1001498746.png
# ...
