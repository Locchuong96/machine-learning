# %% [markdown]
# https://vitalitylearning.medium.com/running-cuda-in-google-colab-525a92efcf75
#
# https://stackoverflow.com/questions/50560395/how-to-install-cuda-in-google-colab-gpus
#
# https://stackoverflow.com/questions/53422407/different-cuda-versions-shown-by-nvcc-and-nvidia-smi
#
# https://forums.developer.nvidia.com/t/path-ld-library-path/48080
#
# https://developer.nvidia.com/cuda-downloads
#
# https://developer.nvidia.com/cuda-toolkit-archive

# %%
# !nvidia-smi
# Out:
# Fri May 19 03:45:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    28W /  70W |    103MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1944      C   node                              100MiB |
# +-----------------------------------------------------------------------------+

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 20.04.5 LTS
# Release:	20.04
# Codename:	focal

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/andreinechaev/nvcc4jupyter.git
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-qxzq10g3
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-qxzq10g3
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit aac710a35f52bb78ab34d2e52517237941399eff
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: NVCCPlugin
#   Building wheel for NVCCPlugin (setup.py) ... done
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4287 sha256=3b0f9927df758501d0a7ca844d084906229620d658fd48d9eeb19350428a2ac3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fo4f97i2/wheels/a8/b9/18/23f8ef71ceb0f63297dd1903aedd067e6243a68ea756d6feea
# Successfully built NVCCPlugin
# Installing collected packages: NVCCPlugin
# Successfully installed NVCCPlugin-0.0.2

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/src
# Out bin /content/result.out

# %%
# %%cuda --name testGoogleColab.cu
#
# #include <stdio.h>
#
# #define gpuErrchk(ans) { gpuAssert((ans), __FILE__, __LINE__); }
# inline void gpuAssert(cudaError_t code, const char* file, int line, bool abort = true)
# {
#     if (code != cudaSuccess)
#     {
#         fprintf(stderr, "GPUassert: %s %s %d\n", cudaGetErrorString(code), file, line);
#         if (abort) exit(code);
#     }
# }
#
# __global__ void add(int a, int b, int *c) {
#    *c = a + b; }
#
# int main() {
#
#    // --- Host declarations and initializations
#    int a, b, c;
#    a = 2;
#    b = 6;
#
#    // --- Device allocations
#    int *d_c; gpuErrchk(cudaMalloc(&d_c, sizeof(int)));
#
#    // --- Kernel execution
#    add<<<1,1>>>(a, b, d_c);
#    gpuErrchk(cudaPeekAtLastError());
#    gpuErrchk(cudaDeviceSynchronize());
#
#    // --- Moving the results from device to host
#    gpuErrchk(cudaMemcpy(&c, d_c, sizeof(int), cudaMemcpyDeviceToHost));
#
#    // --- Results printout
#    printf("%d + %d is %d\n", a, b, c);
#
#    return 0; }
# Out:
# 'File written in /content/src/testGoogleColab.cu'

# %%
# !pip install pycuda
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycuda
#   Downloading pycuda-2022.2.2.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda)
#   Downloading pytools-2022.1.14.tar.gz (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pycuda) (1.4.4)
# Collecting mako (from pycuda)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2011.2->pycuda) (3.3.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2011.2->pycuda) (4.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from mako->pycuda) (2.1.2)
# Building wheels for collected packages: pycuda, pytools
#   Building wheel for pycuda (pyproject.toml) ... done
#   Created wheel for pycuda: filename=pycuda-2022.2.2-cp310-cp310-linux_x86_64.whl size=661975 sha256=7feab284fde989f67d3016b22d33ff35844db6484ca4f83175386cf2c4f1ba3f
#   Stored in directory: /root/.cache/pip/wheels/1d/7b/06/82a395a243fce00035dea9914d92bbef0013401497d849f8bc
#   Building wheel for pytools (setup.py) ... done
#   Created wheel for pytools: filename=pytools-2022.1.14-py2.py3-none-any.whl size=69855 sha256=af2a869d62e04b97bf1699265e04408377454ff2f30e541e2d32add419f3b2bd
#   Stored in directory: /root/.cache/pip/wheels/19/02/16/aa2498ad7aa723a149ff7539f1918509661c0ae9d975b44b6d
# Successfully built pycuda pytools
# Installing collected packages: pytools, mako, pycuda
# Successfully installed mako-1.2.4 pycuda-2022.2.2 pytools-2022.1.14

# %%
import pycuda.driver as drv
import pycuda.autoinit
drv.init()
print("%d device(s) found." % drv.Device.count())
for i in range(drv.Device.count()):
  dev = drv.Device(i)
  print("Device #%d: %s" % (i, dev.name()))
  print(" Compute Capability: %d.%d" % dev.compute_capability())
  print(" Total Memory: %s GB" % (dev.total_memory() // (1024 * 1024 * 1024)))
# Out:
# 1 device(s) found.
# Device #0: Tesla T4
#  Compute Capability: 7.5
#  Total Memory: 14 GB

# %%
# !nvcc -arch=sm_75 -o "/content/src/testGoogleColab.o" /content/src/testGoogleColab.cu

# %%
# !chmod 755 /content/src/testGoogleColab.o
# !/content/src/testGoogleColab.o
# Out:
# 2 + 6 is 8

# %%
# %cd /usr/local/
# Out:
# /usr/local

# %%
# %pwd
# Out:
# '/usr/local'

# %%
# %ls
# Out:
# bin/
# colab/
# cuda@
# cuda-11@
# cuda-11.8/
# cuda-12@
# cuda-12.1/
# cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# etc/
# games/
# _gcs_config_ops.so/
# include/
# lib/
# lib64/
# licensing/
# man@
# sbin/
# share/
# src/

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Out:
# --2023-05-19 04:06:40--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [application/octet-stream]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2023-05-19 04:06:40 (5.28 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]

# %%
# !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# Out:
# --2023-05-19 04:07:49--  https://developer.download.nvidia.com/compute/cuda/10.2/Prod/local_installers/cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1896270068 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb’
#
# cuda-repo-ubuntu180 100%[===================>]   1.77G   241MB/s    in 7.3s
#
# 2023-05-19 04:07:56 (247 MB/s) - ‘cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb’ saved [1896270068/1896270068]

# %%
# !sudo dpkg -i cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# Out:
# Selecting previously unselected package cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01.
# (Reading database ... 141200 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01 (1.0-1) ...
# Setting up cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01 (1.0-1) ...

# %%
# !sudo apt-key add /var/cuda-repo-10-2-local-10.2.89-440.33.01/7fa2af80.pub
# Out:
# OK

# %%
# !sudo apt-get update
# Out:
# Get:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Ign:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  InRelease
# Ign:2 file:/var/cuda-repo-9-2-local  InRelease
# Get:3 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release [574 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:5 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release.gpg [833 B]
# Get:5 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Release.gpg [833 B]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Hit:13 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:14 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:15 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Get:16 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  Packages [23.8 kB]
# Hit:17 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:18 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done

# %%
# !sudo apt-get -y install cuda-10.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-10-2' for regex 'cuda-10.2'
# Note, selecting 'libcuda-10.2-1' for regex 'cuda-10.2'
# The following additional packages will be installed:
#   cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2
#   cuda-cupti-10-2 cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2
#   cuda-cusolver-10-2 cuda-cusolver-dev-10-2 cuda-cusparse-10-2
#   cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2
#   cuda-nsight-compute-10-2 cuda-nsight-systems-10-2 cuda-nvcc-10-2
#   cuda-nvdisasm-10-2 cuda-nvgraph-10-2 cuda-nvgraph-dev-10-2 cuda-nvjpeg-10-2
#   cuda-nvjpeg-dev-10-2 cuda-nvml-dev-10-2 cuda-nvprof-10-2 cuda-nvprune-10-2
#   cuda-nvrtc-10-2 cuda-nvrtc-dev-10-2 cuda-nvtx-10-2 cuda-nvvp-10-2
#   cuda-runtime-10-2 cuda-samples-10-2 cuda-sanitizer-api-10-2
#   cuda-toolkit-10-2 cuda-tools-10-2 cuda-visual-tools-10-2 freeglut3
#   freeglut3-dev libcublas-dev libcublas10 libxfixes-dev libxi-dev libxmu-dev
#   libxmu-headers x11proto-input-dev
# The following NEW packages will be installed:
#   cuda-10-2 cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2
#   cuda-cupti-10-2 cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2
#   cuda-cusolver-10-2 cuda-cusolver-dev-10-2 cuda-cusparse-10-2
#   cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2
#   cuda-nsight-compute-10-2 cuda-nsight-systems-10-2 cuda-nvcc-10-2
#   cuda-nvdisasm-10-2 cuda-nvgraph-10-2 cuda-nvgraph-dev-10-2 cuda-nvjpeg-10-2
#   cuda-nvjpeg-dev-10-2 cuda-nvml-dev-10-2 cuda-nvprof-10-2 cuda-nvprune-10-2
#   cuda-nvrtc-10-2 cuda-nvrtc-dev-10-2 cuda-nvtx-10-2 cuda-nvvp-10-2
#   cuda-runtime-10-2 cuda-samples-10-2 cuda-sanitizer-api-10-2
#   cuda-toolkit-10-2 cuda-tools-10-2 cuda-visual-tools-10-2 freeglut3
#   freeglut3-dev libcublas-dev libcublas10 libxfixes-dev libxi-dev libxmu-dev
#   libxmu-headers x11proto-input-dev
# 0 upgraded, 58 newly installed, 0 to remove and 26 not upgraded.
# Need to get 503 kB/1,429 MB of archives.
# After this operation, 3,476 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-license-10-2 10.2.89-1 [16.4 kB]
# Get:2 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-misc-headers-10-2 10.2.89-1 [1,111 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu-headers all 2:1.1.3-0ubuntu1 [54.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu-dev amd64 2:1.1.3-0ubuntu1 [49.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes-dev amd64 1:5.0.3-2 [11.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-input-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libxi-dev amd64 2:1.7.10-0ubuntu1 [187 kB]
# Get:10 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvcc-10-2 10.2.89-1 [37.4 MB]
# Get:11 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cuobjdump-10-2 10.2.89-1 [88.5 kB]
# Get:12 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvprune-10-2 10.2.89-1 [39.5 kB]
# Get:13 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-compiler-10-2 10.2.89-1 [2,530 B]
# Get:14 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvdisasm-10-2 10.2.89-1 [22.2 MB]
# Get:15 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-gdb-10-2 10.2.89-1 [2,769 kB]
# Get:16 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvprof-10-2 10.2.89-1 [1,651 kB]
# Get:17 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-sanitizer-api-10-2 10.2.89-1 [2,161 kB]
# Get:18 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-memcheck-10-2 10.2.89-1 [139 kB]
# Get:19 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cudart-10-2 10.2.89-1 [111 kB]
# Get:20 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-driver-dev-10-2 10.2.89-1 [11.8 kB]
# Get:21 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cudart-dev-10-2 10.2.89-1 [491 kB]
# Get:22 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cupti-10-2 10.2.89-1 [8,169 kB]
# Get:23 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cupti-dev-10-2 10.2.89-1 [2,197 kB]
# Get:24 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvtx-10-2 10.2.89-1 [38.9 kB]
# Get:25 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-command-line-tools-10-2 10.2.89-1 [27.0 kB]
# Get:26 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-10-2 10.2.89-1 [2,582 B]
# Get:27 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvvp-10-2 10.2.89-1 [2,532 B]
# Get:28 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvrtc-10-2 10.2.89-1 [6,413 kB]
# Get:29 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvrtc-dev-10-2 10.2.89-1 [8,822 B]
# Get:30 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusolver-10-2 10.2.89-1 [85.6 MB]
# Get:31 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusolver-dev-10-2 10.2.89-1 [15.2 MB]
# Get:32 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  libcublas10 10.2.2.89-1 [42.2 MB]
# Get:33 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  libcublas-dev 10.2.2.89-1 [42.3 MB]
# Get:34 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cufft-10-2 10.2.89-1 [87.8 MB]
# Get:35 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cufft-dev-10-2 10.2.89-1 [164 MB]
# Get:36 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-curand-10-2 10.2.89-1 [38.9 MB]
# Get:37 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-curand-dev-10-2 10.2.89-1 [39.1 MB]
# Get:38 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusparse-10-2 10.2.89-1 [59.2 MB]
# Get:39 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-cusparse-dev-10-2 10.2.89-1 [59.7 MB]
# Get:40 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-npp-10-2 10.2.89-1 [56.7 MB]
# Get:41 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-npp-dev-10-2 10.2.89-1 [57.6 MB]
# Get:42 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvml-dev-10-2 10.2.89-1 [53.8 kB]
# Get:43 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvjpeg-10-2 10.2.89-1 [1,274 kB]
# Get:44 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvjpeg-dev-10-2 10.2.89-1 [1,213 kB]
# Get:45 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-compute-10-2 10.2.89-1 [3,712 B]
# Get:46 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nsight-systems-10-2 10.2.89-1 [3,130 B]
# Get:47 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvgraph-10-2 10.2.89-1 [44.5 MB]
# Get:48 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-nvgraph-dev-10-2 10.2.89-1 [35.2 MB]
# Get:49 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-visual-tools-10-2 10.2.89-1 [389 MB]
# Get:50 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-tools-10-2 10.2.89-1 [2,496 B]
# Get:51 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-samples-10-2 10.2.89-1 [65.6 MB]
# Get:52 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-documentation-10-2 10.2.89-1 [54.1 MB]
# Get:53 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-libraries-dev-10-2 10.2.89-1 [2,614 B]
# Get:54 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-libraries-10-2 10.2.89-1 [2,584 B]
# Get:55 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-toolkit-10-2 10.2.89-1 [2,830 B]
# Get:56 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-runtime-10-2 10.2.89-1 [2,532 B]
# Get:57 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-demo-suite-10-2 10.2.89-1 [3,880 kB]
# Get:58 file:/var/cuda-repo-10-2-local-10.2.89-440.33.01  cuda-10-2 10.2.89-1 [2,558 B]
# Fetched 503 kB in 13s (39.3 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 58.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package cuda-license-10-2.
# (Reading database ... 141288 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-license-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-misc-headers-10-2.
# Preparing to unpack .../01-cuda-misc-headers-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-misc-headers-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvcc-10-2.
# Preparing to unpack .../02-cuda-nvcc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvcc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-2.
# Preparing to unpack .../03-cuda-cuobjdump-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprune-10-2.
# Preparing to unpack .../04-cuda-nvprune-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprune-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-compiler-10-2.
# Preparing to unpack .../05-cuda-compiler-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-compiler-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-2.
# Preparing to unpack .../06-cuda-nvdisasm-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-gdb-10-2.
# Preparing to unpack .../07-cuda-gdb-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-gdb-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprof-10-2.
# Preparing to unpack .../08-cuda-nvprof-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprof-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-sanitizer-api-10-2.
# Preparing to unpack .../09-cuda-sanitizer-api-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-memcheck-10-2.
# Preparing to unpack .../10-cuda-memcheck-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-memcheck-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-10-2.
# Preparing to unpack .../11-cuda-cudart-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-driver-dev-10-2.
# Preparing to unpack .../12-cuda-driver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-10-2.
# Preparing to unpack .../13-cuda-cudart-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-10-2.
# Preparing to unpack .../14-cuda-cupti-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-dev-10-2.
# Preparing to unpack .../15-cuda-cupti-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvtx-10-2.
# Preparing to unpack .../16-cuda-nvtx-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvtx-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-2.
# Preparing to unpack .../17-cuda-command-line-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-10-2.
# Preparing to unpack .../18-cuda-nsight-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvvp-10-2.
# Preparing to unpack .../19-cuda-nvvp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvvp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-10-2.
# Preparing to unpack .../20-cuda-nvrtc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-10-2.
# Preparing to unpack .../21-cuda-nvrtc-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-10-2.
# Preparing to unpack .../22-cuda-cusolver-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-dev-10-2.
# Preparing to unpack .../23-cuda-cusolver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package libcublas10.
# Preparing to unpack .../24-libcublas10_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas10 (10.2.2.89-1) ...
# Selecting previously unselected package libcublas-dev.
# Preparing to unpack .../25-libcublas-dev_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.2.89-1) ...
# Selecting previously unselected package cuda-cufft-10-2.
# Preparing to unpack .../26-cuda-cufft-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cufft-dev-10-2.
# Preparing to unpack .../27-cuda-cufft-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-10-2.
# Preparing to unpack .../28-cuda-curand-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-dev-10-2.
# Preparing to unpack .../29-cuda-curand-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-10-2.
# Preparing to unpack .../30-cuda-cusparse-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-dev-10-2.
# Preparing to unpack .../31-cuda-cusparse-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-10-2.
# Preparing to unpack .../32-cuda-npp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-dev-10-2.
# Preparing to unpack .../33-cuda-npp-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-2.
# Preparing to unpack .../34-cuda-nvml-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-10-2.
# Preparing to unpack .../35-cuda-nvjpeg-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-dev-10-2.
# Preparing to unpack .../36-cuda-nvjpeg-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-2.
# Preparing to unpack .../37-cuda-nsight-compute-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-systems-10-2.
# Preparing to unpack .../38-cuda-nsight-systems-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-systems-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-10-2.
# Preparing to unpack .../39-cuda-nvgraph-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-10-2.
# Preparing to unpack .../40-cuda-nvgraph-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-visual-tools-10-2.
# Preparing to unpack .../41-cuda-visual-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-tools-10-2.
# Preparing to unpack .../42-cuda-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../43-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../44-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../45-libxmu-headers_2%3a1.1.3-0ubuntu1_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../46-libxmu-dev_2%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../47-libxfixes-dev_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../48-x11proto-input-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-input-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../49-libxi-dev_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Selecting previously unselected package cuda-samples-10-2.
# Preparing to unpack .../50-cuda-samples-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-samples-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-documentation-10-2.
# Preparing to unpack .../51-cuda-documentation-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-documentation-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-dev-10-2.
# Preparing to unpack .../52-cuda-libraries-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-10-2.
# Preparing to unpack .../53-cuda-libraries-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-toolkit-10-2.
# Preparing to unpack .../54-cuda-toolkit-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-toolkit-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-runtime-10-2.
# Preparing to unpack .../55-cuda-runtime-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-runtime-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-demo-suite-10-2.
# Preparing to unpack .../56-cuda-demo-suite-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-10-2.
# Preparing to unpack .../57-cuda-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-10-2 (10.2.89-1) ...
# Setting up libxmu-headers (2:1.1.3-0ubuntu1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up x11proto-input-dev (2019.2-1ubuntu1) ...
# Setting up cuda-license-10-2 (10.2.89-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-nvdisasm-10-2 (10.2.89-1) ...
# Setting up cuda-nvgraph-10-2 (10.2.89-1) ...
# Setting up cuda-nvvp-10-2 (10.2.89-1) ...
# Setting up libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Setting up cuda-misc-headers-10-2 (10.2.89-1) ...
# Setting up cuda-cusolver-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-10-2 (10.2.89-1) ...
# Setting up cuda-nvprune-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-compute-10-2 (10.2.89-1) ...
# Setting up cuda-memcheck-10-2 (10.2.89-1) ...
# Setting up cuda-cudart-10-2 (10.2.89-1) ...
# Setting up libcublas10 (10.2.2.89-1) ...
# Setting up cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Setting up cuda-cusparse-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-10-2 (10.2.89-1) ...
# Setting up cuda-nvcc-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-systems-10-2 (10.2.89-1) ...
# Setting up cuda-nvprof-10-2 (10.2.89-1) ...
# Setting up cuda-curand-10-2 (10.2.89-1) ...
# Setting up cuda-cuobjdump-10-2 (10.2.89-1) ...
# Setting up cuda-nvml-dev-10-2 (10.2.89-1) ...
# Setting up libcublas-dev (10.2.2.89-1) ...
# Setting up cuda-nvtx-10-2 (10.2.89-1) ...
# Setting up cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Setting up cuda-driver-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-10-2 (10.2.89-1) ...
# Setting up cuda-cudart-dev-10-2 (10.2.89-1) ...
# Setting up cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Setting up cuda-npp-10-2 (10.2.89-1) ...
# Setting up cuda-cupti-10-2 (10.2.89-1) ...
# Setting up cuda-cufft-10-2 (10.2.89-1) ...
# Setting up cuda-cupti-dev-10-2 (10.2.89-1) ...
# Setting up cuda-curand-dev-10-2 (10.2.89-1) ...
# Setting up cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Setting up cuda-cufft-dev-10-2 (10.2.89-1) ...
# Setting up cuda-gdb-10-2 (10.2.89-1) ...
# Setting up cuda-command-line-tools-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Setting up cuda-compiler-10-2 (10.2.89-1) ...
# Setting up cuda-npp-dev-10-2 (10.2.89-1) ...
# Setting up cuda-libraries-10-2 (10.2.89-1) ...
# Setting up cuda-samples-10-2 (10.2.89-1) ...
# Setting up cuda-libraries-dev-10-2 (10.2.89-1) ...
# Setting up cuda-runtime-10-2 (10.2.89-1) ...
# Setting up cuda-visual-tools-10-2 (10.2.89-1) ...
# Setting up cuda-documentation-10-2 (10.2.89-1) ...
# Setting up cuda-demo-suite-10-2 (10.2.89-1) ...
# Setting up cuda-tools-10-2 (10.2.89-1) ...
# Setting up cuda-toolkit-10-2 (10.2.89-1) ...
# Setting up cuda-10-2 (10.2.89-1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
# %ls
# Out:
# bin/
# colab/
# cuda@
# cuda-10.2/
# cuda-11@
# cuda-11.8/
# cuda-12@
# cuda-12.1/
# cuda-repo-ubuntu1804-10-2-local-10.2.89-440.33.01_1.0-1_amd64.deb
# etc/
# games/
# _gcs_config_ops.so/
# include/
# lib/
# lib64/
# licensing/
# man@
# sbin/
# share/
# src/

# %%
# !nvidia-smi
# Out:
# Fri May 19 04:18:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    33W /  70W |    103MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1944      C   node                              100MiB |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf cuda

# %%
# !nvidia-smi
# Out:
# Fri May 19 04:19:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    33W /  70W |    103MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1944      C   node                              100MiB |
# +-----------------------------------------------------------------------------+

# %%
# !ln -s /usr/local/cuda-10.2 /usr/local/cuda

# %%
# !stat cuda
# Out:
#   File: cuda -> /usr/local/cuda-10.2
#   Size: 20        	Blocks: 0          IO Block: 4096   symbolic link
# Device: 30h/48d	Inode: 4456763     Links: 1
# Access: (0777/lrwxrwxrwx)  Uid: (    0/    root)   Gid: (    0/    root)
# Access: 2023-05-19 04:19:32.163002769 +0000
# Modify: 2023-05-19 04:19:29.136762462 +0000
# Change: 2023-05-19 04:19:29.136762462 +0000
#  Birth: -

# %%
# !export PATH=/usr/local/cuda-10.2/bin${PATH:+:${PATH}}

# %%
# !export LD_LIBRARY_PATH=/usr/local/cuda-10.2/lib64 {LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}
# Out:
# /bin/bash: line 0: export: `{LD_LIBRARY_PATH:+:/usr/lib64-nvidia}': not a valid identifier

# %%
# !nvidia-smi
# Out:
# Fri May 19 04:20:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    33W /  70W |    103MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1944      C   node                              100MiB |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Wed_Oct_23_19:24:38_PDT_2019
# Cuda compilation tools, release 10.2, V10.2.89
